# %% [markdown]
# # Group Activity: Week 10
#
# This is a group activity to be completed in class during Week 10.
#
# | Item | Details |
# |---|---|
# | Group Size | Maximum 3 students per group |
# | Due Date | Due by the end of class in Week 10 |
# | Submission | Upload to the *In-Class Activity 6* folder in Slate. One submission per group. Designate one member to upload. |
# | Weight | 6.25% of your final grade |
#
# ## Instructions
#
# - Read each question carefully before responding.
# - Record your answers directly in this document in the shaded response boxes below each question.
# - All group members' names must appear at the top of the submitted document.
# - Each group submits one (1) document only.
# - Where code is required, write it clearly — use consistent indentation and include any necessary import statements.
# - Where an explanation is required, be specific — refer to the actual values, parameters, and chart properties in your answer.
#
# ## Group Members
#
# Sign up to a group by navigating to **Management >> Groups** in Slate. All members in the group will receive the same mark.

# %% [markdown]
# ### Overview
#
# This lab introduces **web-based dashboard development with Dash** using the Titanic dataset.
#
# Students will build an interactive Python dashboard that includes:
#
# - **A structured layout**
# - **User input controls**
# - **Callback functions**
# - **Interactive graphs **
#
#
# The goal is to help in understanding the transition from creating one-off Plotly visualizations to developing a small, fully functional analytical application.

# %% [markdown]
# ### Lab Questions [ 4 Points]
#
# Answer these before coding:
#
# - What is the difference between a static figure and a dashboard?
# - What does a callback do in Dash?
# - Why might a dropdown be useful in a dashboard?
# - Note: After each code cell (- 4 points penalty if not completed):
#     - States the purpose of the cell (what it’s trying to achieve).
#     - Briefly explains the key lines of code and how they connect to the Titanic dashboard (layout, inputs, outputs, filtering, plotting, etc.).

# %% [markdown]
# ### Part 1: App setup - [3 Points]
#
# ### Student task
#
# Prepare the Titanic dataset for use in your dashboard.
#
# Complete the following steps:
#
# - Import `seaborn`, `pandas`, `plotly.express`, and the required Dash components.
# - Load the Titanic dataset using `sns.load_dataset("titanic")`.
# - Display the dataset information using `df.info()` to inspect the available columns and data types.
# - Convert the `survived` column into more readable labels:
#   - `0` → `"Did not survive"`
#   - `1` → `"Survived"`
# - Convert the `pclass` column into more readable labels:
#   - `1` → `"First"`
#   - `2` → `"Second"`
#   - `3` → `"Third"`
#
# After completing these steps, your dataset should be ready to use in the dashboard.

# %%
import seaborn as sns
import pandas as pd 
import plotly.express as px 
from dash import Dash, dcc, html, dash_table, Input, Output 
 
# Load dataset 

 
# Optional readable labels
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# ### Part 2: Build the basic layout [ 8 Points]
#
# Dash layouts are composed of Python objects using HTML and Dash components.
# A simple app can include a title, filters, graphs, and a data table inside `app.layout`.
#
# ### Student task
#
# Build the basic layout for your Titanic dashboard.
#
# Your layout should include:
#
# - A main title called **Titanic Dashboard**
# - A dropdown menu labeled **Select class**
# - Dropdown options for:
#   - `All`
#   - `First`
#   - `Second`
#   - `Third`
# - Two graphs:
#   - `survival-chart`
#   - `fare-chart`

# %%
app = Dash(__name__)

# %% [markdown]
# ### Checkpoint questions [3 Points]
#
# - **Which components are inputs?**
# - **Which components are outputs?**
# - **Which part of the code defines what the user sees first?**

# %% [markdown]
# ### Part 3: Create the callback for 2 Figures [8 Points]
#
# Dash callbacks connect component properties.
# In this part , the selected dropdown value drives the chart output.
# ### Student task
#
# Write a callback that updates the `survival-chart` based on the class selected in the dropdown.
#
# Your callback should:
#
# - Take the selected value from `class-dropdown` as input.
# - Update the `figure` property of `survival-chart` as output.
# - Use the full dataset when the selected value is `"All"`.
# - Otherwise, filter the dataset by the selected passenger class.
# - Create a histogram showing the counts in the `survived` column.
# - Color the bars by `survived`.
# - Display the counts on the bars.
# - Set the chart title to **Survival Counts**.
# -  Create a  `fare distribution chart` using Plotly. Use a histogram with fare on the x-axis and choose an appropriate number of bins. Add a clear title and axis labels, and apply a clean layout style.
# - Return the final figures.
#
# After writing the callback, run the app and verify that the chart updates when you choose a different class from the dropdown.

# %% [markdown]
# ### Student task [ 2 Points]
#
# Run the app and verify that changing the dropdown updates the graph.

# %%
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Student task - Bonus
#
# Create a second Dash dashboard using the Titanic dataset.
#
# Your new dashboard should:
#
# - Include a different layout from the example shown earlier.
# - Use at least one **new callback** with a different input-output relationship.
# - Explore a different question about the Titanic data, such as fare distribution, age patterns, embarkation, or survival by another variable.
# - Include at least one interactive component, such as a dropdown, radio buttons, or a slider.
# - Display the result in a graph or table.
#
# Make sure your callback updates the output correctly when the user changes the selected input.
